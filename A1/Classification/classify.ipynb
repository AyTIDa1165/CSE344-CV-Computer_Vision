# %%
import wandb
import os
import random
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
import seaborn as sns
from torchvision.transforms import v2
from torch.utils.data import DataLoader
from dataset_class import CustomImageDataset
from model_class import ConvNet, ResNet18
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.manifold import TSNE

# %%
config = dict(
    epochs=10,
    batch_size=32,
    learning_rate=0.001,
    dataset="russian-wildlife-dataset",
    architecture="CNN",
    seed=2022028)

# %%
class_names = ['amur_leopard', 'amur_tiger', 'birds', 'black_bear', 'brown_bear', 'dog', 'roe_deer', 'sika_deer', 'wild_boar', 'people' ]
img_dir = 'russian-wildlife-dataset/Cropped_final'  
images = []
labels = []
for i in range(len(class_names)):
    class_dir = os.path.join(img_dir, class_names[i])
    class_size = 0
    try:
        for img_name in os.listdir(class_dir):
            img_path = os.path.join(class_names[i], img_name)
            images.append(img_path)
            labels.append(i)

    except FileNotFoundError:
        print(f"Directory for label '{class_names[i]}' not found")

train_images, val_images, train_labels, val_labels = train_test_split(images, labels, test_size=0.2, stratify=labels, random_state = config['seed'])

# %%
def visualize(class_names, labels, title, color= 'skyblue'):
    distribution = [0] * len(class_names)
    for i in labels:
        distribution[i] += 1
    print(f"{title}:")
    for name, count in zip(class_names, distribution):
        print(f"  {name}: {count}")

    keys = class_names
    values = distribution
    plt.figure(figsize=(10, 5))
    plt.bar(keys, values, color=color, edgecolor='black')
    plt.xlabel("Class Names")
    plt.ylabel("Number of Samples")
    plt.title(title)
    plt.xticks(rotation=45, ha='right')  
    plt.show()

# %%
visualize(class_names, train_labels, "Training Data Distribution", color='skyblue')
visualize(class_names, val_labels, "Validation Data Distribution", color='orange')
# Out:
# Training Data Distribution:
#   amur_leopard: 783
#   amur_tiger: 839
#   birds: 1157
#   black_bear: 780
#   brown_bear: 967
#   dog: 970
#   roe_deer: 899
#   sika_deer: 1231
#   wild_boar: 1148
#   people: 560
# Validation Data Distribution:
#   amur_leopard: 195
#   amur_tiger: 210
#   birds: 289
#   black_bear: 195
#   brown_bear: 242
#   dog: 243
#   roe_deer: 225
#   sika_deer: 308
#   wild_boar: 287
#   people: 140

# %%
def train(train_dataloader, val_dataloader, device, model, criterion, optimizer, config, model_name):
    best_val_loss = float("inf")
    for epoch in range(config.epochs):
        model.train()
        train_loss = 0.0
        val_loss = 0.0
        num_train_samples = 0
        num_val_samples = 0
        for images, labels in train_dataloader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            curr_batch_size = images.size(0)
            train_loss += loss.item() * curr_batch_size
            num_train_samples += curr_batch_size

        average_train_loss = train_loss/num_train_samples

        model.eval()
        with torch.no_grad():
            for images, labels in val_dataloader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)

                curr_batch_size = images.size(0)
                val_loss += loss.item() * curr_batch_size
                num_val_samples += curr_batch_size

        average_val_loss = val_loss/num_val_samples

        wandb.log({"epoch": epoch + 1, "train_loss": average_train_loss, "val_loss": average_val_loss})
        print(f"EPOCH: {epoch+1} | TRAIN LOSS: {average_train_loss} | VAL LOSS: {average_val_loss}")

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), f"weights/{model_name}.pth")
    print(f"weights saved at weights/{model_name}.pth")

# %%
def test(val_dataloader, device, weight_dir, model_class, class_names):
    model = model_class().to(device)
    model.load_state_dict(torch.load(weight_dir))
    model.eval()
    
    preds = []
    y_true = []
    with torch.no_grad():
        for images, labels in val_dataloader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, pred_batch = torch.max(outputs.data, 1)
            preds.extend(pred_batch.tolist())
            y_true.extend(labels.tolist())
        wandb.log({"conf_mat" : wandb.plot.confusion_matrix(probs=None, preds=preds, y_true=y_true, class_names=class_names)})
        print("confusion matrix saved to wandb")
        accuracy = sum(np.array(preds) == np.array(y_true)) / len(y_true)
        f1 = f1_score(y_true, preds, average="weighted")
        print(f"ACCURACY: {accuracy:.4f}")
        print(f"F1 SCORE: {f1:.4f}")

# %%
def visualize_misclassified(val_dataloader, device, weight_dir, model_class):
    model = model_class().to(device)
    model.load_state_dict(torch.load(weight_dir))
    model.eval()
    with torch.no_grad():
        for class_num in range(3):
            print(f"Class Label: {class_num}")
            counter = 0
            for images, labels in val_dataloader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                _, preds = torch.max(outputs.data, 1)
                preds = preds.tolist()
                y_true = labels.tolist()

                for itr in range(len(y_true)):
                    if y_true[itr] == class_num and preds[itr] != class_num:
                        counter += 1
                        print(f'Predicted Label: {preds[itr]} True Label: {y_true[itr]}')
                        image_numpy = images[itr].permute(1, 2, 0).cpu().numpy()
                        plt.imshow(image_numpy)
                        plt.axis("off")
                        plt.show()
                
                    if counter == 3:
                        break
                    
                if counter == 3:
                    break

# %%
def extract_features(dataloader, device, weight_dir):
    all_features = []
    all_labels = []
    model = ResNet18().to(device)
    model.load_state_dict(torch.load(weight_dir))
    model.eval()
    with torch.no_grad():
        for images, labels in dataloader:
            images = images.to(device)

            backbone_model = nn.Sequential(*list(model.children())[:-1]).to(device)
            features = backbone_model(images)
            features = features.view(features.size(0), -1)
            all_features.append(features.cpu().numpy())
            all_labels.append(labels.cpu().numpy())

    return np.concatenate(all_features), np.concatenate(all_labels)

# %%
def plot_tsne2d(dataloader, device, weight_dir, title):
    tsne = TSNE(n_components=2, perplexity=25, random_state=2022028)
    features, labels= extract_features(dataloader, device, weight_dir)
    embedded_features = tsne.fit_transform(features)

    plt.figure(figsize=(8, 6))
    sns.scatterplot(x=embedded_features[:, 0], y=embedded_features[:, 1], hue=labels, palette="bright", alpha=0.7)
    plt.title(title)
    plt.legend(title="Classes")
    plt.show()

# %%
def plot_tsne3d(dataloader, device, weight_dir, title):
    tsne = TSNE(n_components=2, perplexity=5, random_state=2022028)
    features, labels= extract_features(dataloader, device, weight_dir)
    embedded_features = tsne.fit_transform(features)

    tsne = TSNE(n_components=3, perplexity=30, random_state=2022028)
    features, labels= extract_features(dataloader, device, weight_dir)
    embedded_features = tsne.fit_transform(features)

    fig = plt.figure(figsize=(10, 7))
    ax = fig.add_subplot(111, projection='3d')
    
    scatter = ax.scatter(
        embedded_features[:, 0], embedded_features[:, 1], embedded_features[:, 2],
        c=labels, cmap='tab10', alpha=0.7
    )
    
    ax.set_title(title)
    ax.set_xlabel("t-SNE Component 1")
    ax.set_ylabel("t-SNE Component 2")
    ax.set_zlabel("t-SNE Component 3")
    
    # Add legend
    legend1 = ax.legend(*scatter.legend_elements(), title="Classes")
    ax.add_artist(legend1)
    
    plt.show()

# %%
def model_pipeline(model_name, config, is_train=False, is_test=False, get_tsne = False, get_visualize_misclassified=False):
    wandb.login()
    with wandb.init(project=model_name, config=config):
        config = wandb.config

        random.seed(config.seed)
        np.random.seed(config.seed)
        torch.manual_seed(config.seed)
        if torch.cuda.is_available():
            torch.cuda.manual_seed_all(config.seed)

        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        
        transform = v2.Compose([
            v2.ConvertImageDtype(torch.float32),
            v2.Resize((224, 224)),
            v2.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
        ])

        transform_aug = v2.Compose([
            v2.RandomHorizontalFlip(p=0.5),
            v2.ColorJitter(brightness=0.05, contrast=0.05, saturation=0.05),
            v2.GaussianBlur(kernel_size=3, sigma=(0.1, 2.0)),
            v2.ConvertImageDtype(torch.float32),
            v2.Resize((224, 224)), 
            v2.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
        ])

        if model_name == "convnet":
            train_dataset = CustomImageDataset(img_dir, train_images, train_labels, transform=transform)
            model_class = ConvNet
            weight_dir = "weights/convnet.pth"
        elif model_name == "resnet":
            train_dataset = CustomImageDataset(img_dir, train_images, train_labels, transform=transform)
            model_class = ResNet18
            weight_dir = "weights/resnet.pth"

        elif model_name == "resnet_aug":
            train_dataset = CustomImageDataset(img_dir, train_images, train_labels, transform=transform_aug)
            model_class = ResNet18
            weight_dir = "weights/resnet_aug.pth"
        else:
            raise ValueError(f"Unknown model name: {model_name}")
        train_dataloader = DataLoader(train_dataset, config.batch_size, shuffle=True)

        val_dataset = CustomImageDataset(img_dir, val_images, val_labels, transform=transform)
        val_dataloader = DataLoader(val_dataset, config.batch_size, shuffle=False)
        
        if is_train:
            model = model_class().to(device)        
            criterion = nn.CrossEntropyLoss()
            optimizer = optim.Adam(model.parameters(), lr=config.learning_rate)
            print(f"Training {model_name}:")
            train(train_dataloader, val_dataloader, device, model, criterion, optimizer, config, model_name)

        if is_test:
            print(f"Evaluation of {model_name} on VAL SET:")
            test(val_dataloader, device, weight_dir, model_class, class_names)

        if get_tsne and model_name == "resnet":
            # plot_tsne2d(train_dataloader, device, weight_dir, "2D t-SNE of Training Data")
            plot_tsne2d(val_dataloader, device, weight_dir, "2D t-SNE of Val Data")
            # plot_tsne3d(val_dataloader, device, weight_dir, "3D t-SNE of Val Data")

        if get_visualize_misclassified:
            visualize_misclassified(val_dataloader, device, weight_dir, model_class)

# %%
model_pipeline(model_name="convnet", config=config, is_test=True)
# Out:
# wandb: Currently logged in as: aditya22028 (aditya22028-indraprastha-institute-of-information-techno) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# Tracking run with wandb version 0.19.5
# Run data is saved locally in <code>c:\Users\Aditya\Desktop\CV\2022028_HW1\Classification\wandb\run-20250222_035040-pc18klk8</code>
# Syncing run <strong><a href='https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/convnet/runs/pc18klk8' target="_blank">mild-jazz-5</a></strong> to <a href='https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/convnet' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/convnet' target="_blank">https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/convnet</a>
#  View run at <a href='https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/convnet/runs/pc18klk8' target="_blank">https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/convnet/runs/pc18klk8</a>
# Evaluation of convnet on VAL SET:
# confusion matrix saved to wandb
# ACCURACY: 0.6384
# F1 SCORE: 0.6332
#  View run <strong style="color:#cdcd00">mild-jazz-5</strong> at: <a href='https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/convnet/runs/pc18klk8' target="_blank">https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/convnet/runs/pc18klk8</a><br> View project at: <a href='https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/convnet' target="_blank">https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/convnet</a><br>Synced 5 W&B file(s), 1 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250222_035040-pc18klk8\logs</code>

# %%
model_pipeline(model_name="convnet", config=config, get_visualize_misclassified=True)
# Out:
# Tracking run with wandb version 0.19.5
# Run data is saved locally in <code>c:\Users\Aditya\Desktop\CV\2022028_HW1\Classification\wandb\run-20250222_204017-grn27owz</code>
# Syncing run <strong><a href='https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/convnet/runs/grn27owz' target="_blank">magic-water-12</a></strong> to <a href='https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/convnet' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/convnet' target="_blank">https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/convnet</a>
#  View run at <a href='https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/convnet/runs/grn27owz' target="_blank">https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/convnet/runs/grn27owz</a>
# Class Label: 0
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.838471..2.6144674].
# Predicted Label: 1 True Label: 0
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.6671417..0.5311305].
# Predicted Label: 1 True Label: 0
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.0205626..2.5080204].
# Predicted Label: 8 True Label: 0
# Class Label: 1
# Predicted Label: 0 True Label: 1
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.7975227..2.2142625].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.8474138..2.5242362].
# Predicted Label: 5 True Label: 1
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.3834306..2.6400006].
# Predicted Label: 6 True Label: 1
# Class Label: 2
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.21910563..2.2629902].
# Predicted Label: 0 True Label: 2
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.5921174..2.6352973].
# Predicted Label: 6 True Label: 2
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.4324607..2.6394088].
# Predicted Label: 4 True Label: 2
#  View run <strong style="color:#cdcd00">magic-water-12</strong> at: <a href='https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/convnet/runs/grn27owz' target="_blank">https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/convnet/runs/grn27owz</a><br> View project at: <a href='https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/convnet' target="_blank">https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/convnet</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250222_204017-grn27owz\logs</code>

# %%
model_pipeline(model_name="resnet", config=config, is_test=True)
# Out:
# Tracking run with wandb version 0.19.5
# Run data is saved locally in <code>c:\Users\Aditya\Desktop\CV\2022028_HW1\Classification\wandb\run-20250222_035123-cfl2gg62</code>
# Syncing run <strong><a href='https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/resnet/runs/cfl2gg62' target="_blank">rural-water-4</a></strong> to <a href='https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/resnet' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/resnet' target="_blank">https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/resnet</a>
#  View run at <a href='https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/resnet/runs/cfl2gg62' target="_blank">https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/resnet/runs/cfl2gg62</a>
# Evaluation of resnet on VAL SET:
# confusion matrix saved to wandb
# ACCURACY: 0.8355
# F1 SCORE: 0.8355
#  View run <strong style="color:#cdcd00">rural-water-4</strong> at: <a href='https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/resnet/runs/cfl2gg62' target="_blank">https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/resnet/runs/cfl2gg62</a><br> View project at: <a href='https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/resnet' target="_blank">https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/resnet</a><br>Synced 5 W&B file(s), 1 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250222_035123-cfl2gg62\logs</code>

# %%
model_pipeline(model_name="resnet", config=config, get_tsne=True)
# Out:
# Tracking run with wandb version 0.19.5
# Run data is saved locally in <code>c:\Users\Aditya\Desktop\CV\2022028_HW1\Classification\wandb\run-20250223_180300-04tazr2i</code>
# Syncing run <strong><a href='https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/resnet/runs/04tazr2i' target="_blank">vocal-shape-16</a></strong> to <a href='https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/resnet' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/resnet' target="_blank">https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/resnet</a>
#  View run at <a href='https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/resnet/runs/04tazr2i' target="_blank">https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/resnet/runs/04tazr2i</a>
#  View run <strong style="color:#cdcd00">vocal-shape-16</strong> at: <a href='https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/resnet/runs/04tazr2i' target="_blank">https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/resnet/runs/04tazr2i</a><br> View project at: <a href='https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/resnet' target="_blank">https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/resnet</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250223_180300-04tazr2i\logs</code>

# %%
model_pipeline(model_name="resnet", config=config, get_tsne=True)
# Out:
# Tracking run with wandb version 0.19.5
# Run data is saved locally in <code>c:\Users\Aditya\Desktop\CV\2022028_HW1\Classification\wandb\run-20250222_175420-3miura57</code>
# Syncing run <strong><a href='https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/resnet/runs/3miura57' target="_blank">lucky-dust-11</a></strong> to <a href='https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/resnet' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/resnet' target="_blank">https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/resnet</a>
#  View run at <a href='https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/resnet/runs/3miura57' target="_blank">https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/resnet/runs/3miura57</a>
#  View run <strong style="color:#cdcd00">lucky-dust-11</strong> at: <a href='https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/resnet/runs/3miura57' target="_blank">https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/resnet/runs/3miura57</a><br> View project at: <a href='https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/resnet' target="_blank">https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/resnet</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250222_175420-3miura57\logs</code>

# %%
model_pipeline(model_name="resnet_aug", config=config, is_test=True)
# Out:
# Tracking run with wandb version 0.19.5
# Run data is saved locally in <code>c:\Users\Aditya\Desktop\CV\2022028_HW1\Classification\wandb\run-20250222_192724-jmkz6wd8</code>
# Syncing run <strong><a href='https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/resnet_aug/runs/jmkz6wd8' target="_blank">sage-shape-14</a></strong> to <a href='https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/resnet_aug' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/resnet_aug' target="_blank">https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/resnet_aug</a>
#  View run at <a href='https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/resnet_aug/runs/jmkz6wd8' target="_blank">https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/resnet_aug/runs/jmkz6wd8</a>
# Evaluation of resnet_aug on VAL SET:
# confusion matrix saved to wandb
# ACCURACY: 0.8496
# F1 SCORE: 0.8492
#  View run <strong style="color:#cdcd00">sage-shape-14</strong> at: <a href='https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/resnet_aug/runs/jmkz6wd8' target="_blank">https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/resnet_aug/runs/jmkz6wd8</a><br> View project at: <a href='https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/resnet_aug' target="_blank">https://wandb.ai/aditya22028-indraprastha-institute-of-information-techno/resnet_aug</a><br>Synced 5 W&B file(s), 1 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20250222_192724-jmkz6wd8\logs</code>

# %%
def visualize_augmentation():
            
    transform = v2.Compose([
        v2.ConvertImageDtype(torch.float32),
        v2.Resize((224, 224)),
    ])

    transform_aug = v2.Compose([
        v2.RandomHorizontalFlip(p=0.5),
        v2.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
        v2.GaussianBlur(kernel_size=3, sigma=(0.1, 2.0)),
        v2.ConvertImageDtype(torch.float32),
        v2.Resize((224, 224)), 
        v2.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])

    dataset = CustomImageDataset(img_dir, train_images, train_labels, transform=transform)
    transformed_dataset = CustomImageDataset(img_dir, train_images, train_labels, transform=transform_aug)

    for i in range(5, 10):
        fig, ax = plt.subplots(1, 2, figsize=(10, 5))
        image, _ = dataset.__getitem__(i)
        transformed_image, _ = transformed_dataset.__getitem__(i)
        image = image.permute(1, 2, 0).numpy()
        transformed_image = transformed_image.permute(1, 2, 0).numpy()

        ax[0].imshow(image)
        ax[0].axis("off")
        ax[0].set_title("Original Image")

        ax[1].imshow(transformed_image)
        ax[1].axis("off")
        ax[1].set_title("Transformed Image")

        plt.show()
visualize_augmentation()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.90324485..1.9400892].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.0218642..1.9424435].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.5461705..1.8170719].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.7362107..2.347027].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.0098882..2.3744206].
